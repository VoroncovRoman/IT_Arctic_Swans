# %%
# Подключаемся к Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Копируем наш архив
# !cp [директория источник] [целевая директория]
# !cp /content/drive/'My Drive'/'train_dataset.zip' /content

# %%
# !unzip -q /content/train_dataset.zip

# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
#display.clear_output()

# %%
# !nvidia-smi
# Out:
# Sat May 20 00:38:29 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# HOME = os.getcwd()
HOME = r'/content/drive/MyDrive/Colab Notebooks'

# %%
print(HOME)
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pip install ultralytics==8.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 21.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.7 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=d474f90751d49c2380d5a8306c8ae9d3efb67b98ebe7ead12d21b76fe0b431d6
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.4/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets

# %%
# !pwd
# Out:
# /content

# %%
cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pwd
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YY9H5U8ELZz0jqHFQhHJ")
project = rf.workspace("roboflow-universe-projects").project("construction-site-safety")
dataset = project.version(27).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 8.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 12.0 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=193302da1117c013760741e40f8fe6c0a885c311c5df02a60c66b89ff1ca9c25
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
# ...

# %%
cd {HOME}
# Out:
# /content

# %%
cd Construction-Site-Safety
# Out:
# [Errno 2] No such file or directory: 'Construction-Site-Safety'
# /content

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8x-seg.pt data=/content/config.yaml epochs=18 imgsz=640
# Out:
# /content/drive/MyDrive/Colab Notebooks
# ...
# 100% 137M/137M [00:06<00:00, 23.4MB/s]
#
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=900)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=segment mode=val model=/content/runs/segment/train/weights/best.pt data=/content/config.yaml
# Out:
# /content
# 2023-04-21 19:41:24.438718: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-21 19:41:25.429882: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /content/datasets/Construction-Site-Safety/valid/labels.cache... 114 images, 10 backgrounds, 0 corrupt: 100% 114/114 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:10<00:00,  1.28s/it]
# ...

# %%
# !zip -r /content.zip /content
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   adding: content/datasets/Construction-Site-Safety/train/labels/youtube-709_jpg.rf.a41ca8d936a0c1c7ba2056f8aee00950.txt (deflated 62%)
#   adding: content/datasets/Construction-Site-Safety/train/labels/youtube-134_jpg.rf.14bdeeebc7224bb1786af220945d3b20.txt (deflated 53%)
#   adding: content/datasets/Construction-Site-Safety/train/labels/image_191_jpg.rf.eeec1b715fe738b70985dd16dd529a86.txt (deflated 60%)
#   adding: content/datasets/Construction-Site-Safety/train/labels/2009_000379_jpg.rf.96decf0b5478e3c1b671ac7ee2a3a289.txt (deflated 55%)
#   adding: content/datasets/Construction-Site-Safety/train/labels/youtube-348_jpg.rf.c478843562d5236a46c6448ecc3344b0.txt (deflated 63%)
#   adding: content/datasets/Construction-Site-Safety/train/labels/-2270-_png_jpg.rf.886787ea83b8aae214e984b7607b90c9.txt (deflated 57%)
# ...
